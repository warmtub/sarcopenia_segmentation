# %%
import torch
import os
import cv2
import matplotlib.pyplot as plt
#from albumentations.augmentations import transforms
#from albumentations.core.composition import Compose, OneOf


#val_transform = Compose([
#    transforms.Resize(384, 512,p=1),
#    transforms.Normalize(),
#])


net = torch.load('U_Net-50-0.0000-35-0.4488.pkl')
_ = net.cuda()
_ = net.eval()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6afa7376d1e9> in <module>
#      14
#      15 net = torch.load('U_Net-50-0.0000-35-0.4488.pkl')
# ---> 16 _ = net.cuda()
#      17 _ = net.eval()
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'cuda'

# %%
img = cv2.imread('busi-cv0/images/36998692_143105_K.png')
plt.imshow(img)
plt.show()

img = torch.tensor(val_transform(image=img)['image']).permute(0,3,1,2).cuda()
output = net(img.unsqueeze(0))
output = output.detach().cpu()

# output is in the form [Batch,C,W,H]
plt.imshow(output[0,0], cmap='jet') # background
plt.show()
plt.imshow(output[0,1], cmap='jet') # benign 
plt.show()
plt.imshow(output[0,2], cmap='jet')   # malignant
plt.show()
